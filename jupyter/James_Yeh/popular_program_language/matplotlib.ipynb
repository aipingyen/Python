# %%
import matplotlib.pyplot as plt
import numpy as np

with open('./final.csv','r') as f:
    lan = f.read().strip().split('\n')
del lan[0]

plt.figure(num=1,figsize=(20,10))

x = np.arange(len(lan))
y = np.array([lan[i].split(',')[1] for i in range(len(lan))])

plt.bar(x,y2,width=0.2)
plt.plot(x,y2,c='red')

for X,Y in zip(x,y):
    plt.text(X,Y,'%s'%Y, ha='center', va='bottom')          #

plt.xticks(x,[lan[i].split(',')[0] for i in range(len(lan))])
plt.title('Programming Language Popular')
plt.xlabel('Programming Language')
plt.ylabel('Count')

plt.show()

# %%
import matplotlib.pyplot as plt

with open('./final.csv','r') as f:
    lan = f.read().strip().split('\n')
del lan[0]

plt.figure(figsize=(8,5))

data = [lan[i].split(',')[1] for i in range(len(lan))]
data.reverse()

labels = [lan[i].split(',')[0] for i in range(len(lan))]
labels.reverse()

plt.barh(range(len(data)), data, tick_label=labels, height=0.5)

ax=plt.gca()         #

for label in ax.get_xticklabels()+ax.get_yticklabels():
    label.set_fontsize(10)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(num=1,figsize=(20,10))                #num
data = [lan[i].split(',')[1] for i in range(len(lan))]
labels = [lan[i].split(',')[0] for i in range(len(lan))]
plt.bar(range(len(data)), data, tick_label=labels, width=0.5)

plt.show()

# %%
#Axes3D
#https://morvanzhou.github.io/tutorials/data-manipulation/plt/3-5-3d/
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
# X, Y value
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
# height value
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow'))
                      #線的跨度，越大越粗糙
ax.contourf(X,Y,Z,zdir='z',offset=-2,cmap='rainbow')
                  #投影方向
ax.set_zlim(-2,2)
plt.show()

# %%
#contourf
import matplotlib.pyplot as plt
import numpy as np

def f(x,y):
    # the height function
    return (1 - x / 2 + x**5 + y**3) * np.exp(-x**2 -y**2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x,y)

plt.contourf(X,Y,f(X,Y),8,alpha=0.75,cmap=plt.cm.hot) #color map

C=plt.contour(X,Y,f(X,Y),8,colors='black',linewidth=0.5)
                        #分八段
plt.clabel(C,inline=True,fontsize=10)
#專門給等高線用的

plt.xticks(())
plt.yticks(())
plt.show()

# %%
#imshow
import matplotlib.pyplot as plt
import numpy as np

# image data
a = np.array([0.313660827978, 0.365348418405, 0.423733120134,
              0.365348418405, 0.439599930621, 0.525083754405,
              0.423733120134, 0.525083754405, 0.651536351379]).reshape(3,3)

"""
for the value of "interpolation", check this:
http://matplotlib.org/examples/images_contours_and_fields/interpolation_methods.html
for the value of "origin"= ['upper', 'lower'], check this:
http://matplotlib.org/examples/pylab_examples/image_origin.html
"""
plt.imshow(a, interpolation='nearest', cmap='bone', origin='lower')
plt.colorbar(shrink=.92)

plt.xticks(())
plt.yticks(())
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

n = 1024
X=np.random.normal(0,1,n)
Y=np.random.normal(0,1,n)
T=np.arctan2(Y,X)

plt.scatter(X,Y,s=75,c=T,alpha=0.5) #s=size, c=color
# plt.scatter(np.arange(5),np.arange(5))

plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))

plt.xticks(()) #消除標籤數值
plt.yticks(())

plt.show()
