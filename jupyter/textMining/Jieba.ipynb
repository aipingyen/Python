# %%
import jieba
wdCut = jieba.cut("今天是星期六",cut_all=False)
#精準比對
strWd = ",".join(wdCut)
strList = strWd.split(',')
strList
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\BIGDAT~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.777 seconds.
# Prefix dict has been built succesfully.
# ['今天', '是', '星期六']

# %%
wdCut = jieba.cut("明天是星期日",cut_all=True)
#模糊比對
strWd = ",".join(wdCut)
strList = strWd.split(',')
strList
# Out:
# ['明天', '是', '星期', '星期日', '期日']

# %%
wdCut = jieba.cut_for_search("星期一約好要一起去淡水玩城市大冒險！")
strWd = ",".join(wdCut)
strWd
# Out:
# '星期,星期一,約,好,要,一起,去,淡水,玩,城市,大冒險,！'

# %%
with open("C:\\Users\\BIG DATA\\Desktop\\safe.txt","r",encoding='utf-8') as fr:    
    strList = []  
    for line in fr:
        line = line.strip().replace(',',"").replace('！',"").replace('~',"").replace('.',"").replace('，',"").replace('-',"")
        strCut=jieba.cut(line,cut_all=False)
        strWd = ",".join(strCut)
#         strList.append(strWd)
#     with open(u'C:\\Users\\BIG DATA\\Desktop\\try.csv','a',encoding="utf-8") as fw:
#         fw.write(strCut+'\n')
    print(strWd)
#         strList

# %%
import jieba
jieba.load_userdict("E:\\PythonWin\\workspace\\dict\\emotionDict\\positiveDict.txt")
#自訂jieba dict
with open("C:\\Users\\BIG DATA\\Desktop\\test.txt","r") as fr:    
    strList = []  
    for line in fr:
        line = line.strip().replace(',',"").replace('！',"").replace('~',"").replace('.',"").replace('，',"").replace('-',"").replace('(',"").replace(')',"")
#         print(line)

        strCut=jieba.cut(line,cut_all=False)
#         print(",".join(strCut))
        strWd = ",".join(strCut)
        strList.append(strWd)
    with open(u'C:\\Users\\BIG DATA\\Desktop\\equip1.csv','a') as fw:
        fw.write('\n'.join(strList)+'\n')
    print(strList)
# Out:
# ['兒童,座椅', 'ISO, ,FIX,兒童,安全,座椅,固定,機構', 'ISO, ,FIX,兒童,座椅,固定,裝置', 'ISO,─,FIX, ,兒童,座椅,固定,裝置', 'ISO,─,FIX, ,兒童,座椅,固定,機構', 'ISOFI, ,後,座,兒童,安全,椅,固定,裝置', 'ISOFIX, ,兒童,安全,座椅,固定,扣', 'ISOFIX, ,兒童,安全,椅,固定,裝置', 'ISOFIX, ,型式,兒童,安全,座椅,固定,裝置', 'ISOFIX, ,後,座,兒童,安全,椅,固定,裝置', 'ISOFIX, ,童,安全,座椅,固定,扣', 'ISOFIX,兒童,安全,座椅,扣環', 'ISOFIX,兒童,安全,座椅,固定,扣', 'ISOFIX,兒童,安全,座椅,固定,裝置', 'ISOFIX,兒童,安全,座椅,固定,裝置', 'ISOFIX,兒童,安全,座椅,固定,機構', 'ISOFIX,兒童,安全,椅安裝,系統', 'ISOFIX,兒童,安全,椅,固定', 'ISOFIX,兒童,座椅,固定,系統', 'ISOFIX,兒童,座椅,固定,裝置', 'ISOFIX,型式,兒童,安全,座椅,固定,裝置', 'ISOFIX,後,座,兒童,安全,座椅,固定,座', 'ISOFIX,後,座,兒童,安全,座椅,固定,座,?', '', '', '', '', '']

# %%
# !pip install jieba
# !pip install encode
# Out:
# ...
#   Could not find a version that satisfies the requirement encode (from versions: )
# No matching distribution found for encode

# %%
with open('E:\\PythonWin\\workspace\\dict\\moedDict\\moedict--revised.txt','r') as frN:
    normal_words = frN.read().split('\n')
with open('E:\\PythonWin\\workspace\\dict\\uselessDict\\stopWords.txt','r',encoding='utf8') as frW:
    stop_words = frW.read().split('\n')
with open('E:\\PythonWin\\workspace\\dict\\uselessDict\\specialSignList.txt','r',encoding='utf8') as frS:
    sign_words = frS.read().split('\n')

# %%
with open('C:\\Users\\BIG DATA\\Desktop\\test.txt') as fr:
    article = fr.read()

from collections import Counter
wc = Counter() # Dictionary like object

for word_raw in article.split():
    word = word_raw.replace(',', '').replace('.', '').lower()
    if word not in normal_words and stop_words and sign_words:
        if word in wc:
            wc[word] += 1
        else:
            wc[word] = 1

# %%
wc.most_common()
# Out:
# [('→', 56),
#  ('06/17', 49),
#  ('06/18', 23),
#  ('06/19', 11),
#  ('oledu:', 10),
#  ('william0808:', 9),
#  ('fun2t:', 7),
#  ('stevely:', 6),
#  ('dye:', 6),
#  ('reallocust:', 6),
#  ('a26237221:', 6),
#  ('hydeless:', 5),
#  ('08:23', 5),
#  ('esla:', 5),
#  ('12:03', 4),
#  ('01:35', 3),
#  ('henry00000:', 3),
#  ('16:19', 3),
#  ('20:45', 3),
#  ('12:24', 3),
#  ('※', 2),
#  ('01:10', 2),
#  ('07:57', 2),
#  ('08:11', 2),
#  ('08:16', 2),
#  ('10:25', 2),
#  ('11:19', 2),
#  ('jfw616:', 2),
#  ('16:23', 2),
#  ('19:40', 2),
#  ('nkac:', 2),
#  ('19:41', 2),
#  ('19:50', 2),
#  ('chenhanhan88:', 2),
#  ('11:24', 2),
#  ('250', 2),
#  ('13:51', 2),
#  ('15:34', 2),
#  ('eijy:', 2),
#  ('18:14', 2),
#  ('smalllwhite:', 2),
#  ('11:07', 2),
#  ('damper:', 2),
#  ('17:18', 2),
#  ('06/20', 2),
#  ('作者william0808', 1),
#  ('(william)', 1),
#  ('看板europeancar', 1),
#  ('標題[問題]', 1),
#  ('s205-c200', 1),
#  ('c250', 1),
#  ('搭配的m274引擎', 1),
#  ('時間sat', 1),
#  ('jun', 1),
# ...

# %%
text="""
聽朋友說車上最好準備一瓶變速箱油,因為這款車會吃油,是這樣嗎?
我也不推薦這間 我的32 大概4年前在哪大修..那是第一次拆引擎
大約2年又開始漏油上蓋..變速箱,最近縮鋼又要大整理,車行在我前面拆 我引擎防火牆前面的蓋板沒裝回去...當初說全部的水管油管都換掉..


最近看起來只換了2/3..廢掉EGR也沒說...當初說要拍的照片也沒拍... 當初花了約7萬多...處理漏油
不推薦高雄仁武澄觀路那間啦~
以前也是看mobile01的PO文去那家保養場

但接連去幾次保養後,就不再願意過去了~

記得有一次,老闆跟我說我的車的風扇,因原廠設計不佳的因素

容易損壞而導致風扇停擺,所以建議我修改風扇接頭

於是我就答應老闆換接頭,總計花費兩個接頭+工資約2000元

但不換還好,換的結果第二個月風扇就燒掉了


風扇燒掉的原因不詳,但我那台車只開4萬公里說,

而家裡另一台頭大大的車, 風扇卻是10萬公里才損壞跟換

還是日產零件的耐用性只有人家的一半?!
是去做5千公里維修,老闆要學徒自己去弄

而那個學徒菜菜的,拆螺絲鎖螺絲都一直把螺絲弄掉在地上

搜尋一下 "宇翔 cefiro" 就可以知道有很多人都會推薦
不是台北的宇翔, 是高雄的宇翔喔於2013年導入國產的Sentra，迄今已邁入第四年，原廠在國外2016年式車型上便已進行過小改款，並導入V-Motion設計語言，台規版當時並未同步跟進，而是推出Sentra Aero年輕化扮相來對應。由於市場反應相當良好，裕隆還將這套台日合作生產開發的套件回銷到日本。不過該改款的動作終究是要來到的，裕隆內部規劃將在今年底前推出小改款Sentra，將原廠V-Motion設計語彙原封不動地重現在新車上。一般預料，Sentra小改款新車將會有著不下於iTiida的亮眼車頭造型，並且也不排除會把此次出現在Tiida上所使用之最新X-Media多媒體系統移植到新Sentra小改款。另一方面，當前市場上所關切的主被動安全議題，勢必也將會是Sentra小改款時必須面對的重要課題。
Sentra我想是神Ａ之外另一個選擇，適合居家使用，

為了讓ＩＩＨＳ成績更好，在車體上很多焊接點都做了改進，

希望Sentra改款也能比照，變得更安全。
改車頭那個馬酷
當然會期待啊!

以目前Sentra現有的優勢

像是大空間、後座出風口、舒適度...等等

再搭配本身品質穩定，二手價也不錯，後續養車也好養

假設若未來針對一些不足的地方去補強

Sentra在這級距上絕對相當有競爭力
把tiida那個渦輪引擎，裝在xtrail上，應該會熱賣吧，有的話，我應該會買單
Teana到現在都還維持第二代，sentra我期望沒有很大
嫌貨才是買貨人。
不然我這台小嘉年華也可以繼續開。
加上外國在使用的渦輪增壓引擎，主被動安全系統滿配，自動煞停系統等等
還是期望 嚴董事長 視實務為俊傑 把台灣總代理經銷權還給 日產總公司就好~


嚴董還是傻B一個 專心用三義做純日產"代工生產" 不用擔心庫存壓力不是很好~


幾百億身價精打細算 不如我一介 小民
sentra 是很有歷史的車型，

伴隨很多五六年級生成長。
外型不潮、油耗不優，

但大器穩重、空間優異、平穩舒適，

對居家型買家還是有吸引力。

如果現型車款補足安全配備，

再引進1.6渦輪  188HP nismo版，

要動力有動力，要空間有空間，就太棒了！

這種希望我看只有等著打臉
真的是不期待就沒傷害

現行的車，連頂規的安全配備都沒配置齊全，真的讓人完全沒有期待感
只要補了6顆氣囊跟循跡，80%的人就不會酸了，剩下我希望有車道偏移跟盲點偵測。這樣我真的就想把我的SS換掉
這只是設計理念不同，照這個邏輯，現代super elantra不就領先神A兩個世代???
多加一款配1.6的引擎, 售價降個6~8萬. 這樣可能多賣個幾百台. 
安全配備增加效果如何不清楚. Better to have, not must to have. 


方向盤,一定要改. 現有方向盤真的難看,肥肥粗粗. 國外早就換成較細較小現代感十足的方向盤了. 都是共用件,國外版本直接拿來用就好了.
主動安全補滿+氣囊6顆以上

嚴董大賺台灣人民錢還盡端一些聞了會吐又嚥不下的鳥菜,只剩X trail能看

八折才符合這個品牌及產品價值
期待他繼續維持2顆球無ESP~定價設在75左右

最重要的是要升級影音系統~至少8顆喇叭

並且搭載NISSAN PLAY~還有台灣人超愛的環景
若是太過強調安全性~把6顆球、ESP加上去~

再加上坡起步輔助系統、陡坡緩降輔助系統、整合式車身動態管理系統、

電子車身防傾系統、ABS、煞車力道輔助系統、煞車優先輔助系統、


還有LED大燈、自動啟閉頭燈、等等~就會上看85~90~

小改款其實就是改外型跟主動式安全補上，方向盤也改比較好看的， 其他沒變， 也就是中國規格的高配。 就是這樣， 其實這台車沒理由賣這麼差，這車新軒逸在中國賣的不比神Ａ差， 內裝比神Ａ好， 座椅舒服，非常適合四人座， 但因為底盤還是有隆起，所以五人座會辛苦點。 至於開的感覺會漸入佳作， 這車的學習適應期有點長， 要過5000才ＯＫ。  


我認為最該改進的地方就是後座椅要能64分離， 雖然它後車廂已經是超大等級。 但遇到長物還是沒輒。 如果不能兩個分離， 一個也行。 裕日車如果有看到一定要試著改進這點。
非常贊同~給你5顆星~

S3每月賣個300都台,S5賣不到100台,不知道在撐甚麼?

關於安全性配備喊到死NISSAN爺不大會理你---檳榔.香菸,安非他命這些吃了會要命,還不是一堆人在吃?
我對台灣的nissan已經死心
豐田都已經醒了
希望有循跡防滑系統

希望有車身動態穩定系統

希望有超高剛性車體

希望馬力150ps 扭力20kg-m

希望標配六安全氣囊

希望標配盲點偵測系統

希望標配PUSH START 單鍵式引擎啟閉系統

希望標配倒車廣角顯影系統

希望標配定速巡航系統

希望標配防前後爆衝系統

希望兩版本及合理售價 65萬(入門)-75萬(頂級)


期望環景系統及影音套餐列為選配即可
我看完Tiida改款成iTiida, 才知道, 原來Nissan台灣如此的堅持與頑固。

消費者重視安全, 他們偏不加回去, 偏要用以前Ceffero時代那種電子花車的策略來塞雞助配備給現在新一代年輕買家。

看著吧~~ 年輕族群會上網路討論和問意見, 在不用多久, 就會把這種廠牌淘汰了。

所以, Super sentra真的不要期待, 也不要在期待這牌國產車能加回安全配備了。

直接看嚴董的納志傑, 或是現代, honda, ford, mazda, 三菱的Grand lancer, 都好過這牌的主流車款太多。

用新台幣, 讓裕日退出Nissan的經營, 讓日產真的自己經營, 自己引進全球一致的戰略車款。

我期待那麼一天的到來~~
把循跡和六氣囊標配
其實Sentra就會是一台非常具有競爭力的車款了
我覺得還是會標配雙安無ESP,頂規還是四安無esp,這家車廠只會改外改外型和音響內裝。

叫他增加安全配備好像會死一樣。

所以不用看這牌的車了，我也從Nissan的車迷變成，抵死都不在買Nissan國產車的消費者。
改個牌價 比較實在

降個20萬差不多
很好我讚同請問台灣日產有出Serena嗎？若沒有，台灣有代購嗎？日本已經有新版了！好實用 想知道進來台灣多少？
沒錯 好車一台 但日本只有右駕版，台灣又早已停產，

如果Nissan 想要引進，要如何跟 嚴老闆 交代？納M7 要賣給誰？
看來好像沒有解套方法！
第一次聽說日規車可以代購的，
Mitsubishi D5也是.
這就是為什麼舊款Serena與SpaceGear滿街跑,

卻沒有新車賣的原因.
同意~ NV200更適合台灣, 而且一堆與現在Tiida 1.6共通料件:引擎,變速箱..........都一樣.

導入台灣的成本很低啊~
Serena沒有生產左駕版，看看NV200説不定比較有機會！但也是0％與1％的差別！
代購能上路嗎?

以及會有相關稅的費用產生吧?
所以可以找代購呀！不過不知道有沒有代購！
已經停產了，因為會壓到納智捷，你現在去問nissan為甚麼停產，nissan一定會說原場報價太高，現在nissan跟renault合作都有許多精彩的車車，可惜在台灣遇到很爛的代理
右駕？請問 X-TRAIL 原車上的行車記錄器影像,

要如何取得在電腦上看??

後鏡頭??  

及 左 . 右 二邊的鏡頭影像??請問各位車友有關於此車不錯的菜單可以介紹嗎?  感謝!
小弟是在台中/新竹，下訂NA豪華版紅色!

最近剛辦Juke論壇會員...還沒時間去好好逛
我是在Juke 論壇有開箱文，我再把內容移過來好了^^ 你可以去Juke 論壇留言喔...  你是在哪個縣市?  那款和顏色呢?
樓主不另外發個開箱文嗎

小弟最近也下訂16/17的豪華版~等待交車中
還是貢獻一下文章跟訊息^^ 小弟最後入手2016出廠/2017仕的Juke NA版。開了兩三天很滿意，站上討論的缺點也有可能是真的(未發生，因為剛開)，優點也是真的。沒有完美的車子，只有適合自己的車子，期望大家都入手自己喜歡的車子 + 開的長長久久沒問題^^如題，完美影音版96.9萬，業務報價89萬(不含規費，保險)，配備如下:
1.原廠絨毛踏墊
2.蜂巢式踏墊(含後車廂)
3.全車FSK隔熱紙，前檔F70,其他的就一般的(型號忘了)
4.廣角鏡
5.冷氣慮網5片
這單OK嗎？
1.原廠絨毛踏墊
一班都換3M防水踏墊吧....

參考官網配件表看看吧
50萬24期0利率，業務說保險可自理，但如果要68保固建議第三責任險和強制險保公司的！
現金還是貸款！剛剛跟一個業務談了一下！92.5那款折6萬！本人33歲！他乙式報價4萬多！貸款的部分他有報兩家銀行2.88跟2.65！所以個人覺得有時候便宜是不是灌水到別的地方去了
大大，你好，最近也在看此車，可否提相關資訊或菜單，謝謝(高雄單更佳)!!
大大方便私訊相關訊息嗎？最近也在看，謝謝^_^
請問是真的嗎? 比我的好多了 3/31南部訂車的人
已私訊
不錯的單，可以介紹一下業務嗎？X-TRAIL 旗艦版4WD 定價118.5萬

1. 12月份交車送 氣流倍增氣
2. 68保固
3. 空濾網 5片
4. 60萬24期零利率( 公司是50萬24期零利率；我多貸10萬，利息業務貼 )
5. 便利收納置物袋
6. 多元收納四件組
1. 八合一防盜
2. 前檔FSK318；車身+天窗 丹龍612
3. 防水踏墊
4. 晴雨窗 四窗
5. 車側踏板
6. 不鏽鋼尾管
7. 後視鏡收折
8. 後背門防刮板

9. 分期動保費 3500

10. 領牌約 4000

11. 廣角鏡

12. Etag

13. 98油加滿 

14. 鯊魚鰭天線

15. 保險實支實付
總成交價 110萬
需要業務資料者，請回文，我在私密
付上訂購單
我們也是最近也在看這款旗艦版。能煩請開版大大分享下業代資訊嗎？謝謝版主
考慮完美影音版，請版主pm業務資訊，謝謝囉！
我也是在台南買的 比你便宜一點點
能煩請開版大大分享下業代資訊嗎？謝謝版主
我們也是最近也在看這款旗艦版。能煩請開版大大分享下業代資訊嗎？謝謝版主
最近小弟也在看百萬左右的SUV

試乘了X-trail覺得除了動力外，其他的都還算不錯

也對於4WD的很有興趣

覺得版大的單開得很棒！

還請板大分享一下業代訊息
原廠建議95(含)以上無鉛汽油即可。

X-trail 2.0壓縮比 較 2.5高，一樣加95.
看個人的需求，有人加95跟98感覺不出差異，

最有感的是油錢差異而已
這張單子可起來折扣相當大!!

把業務贈送的 加上定價折下來的
595000
40萬30期零利
保險強制+第三責4000內
北部單.給你參考
真心覺得買車不能急 在多問幾家看看^_^
我今天去問到行家皮椅精裝影音版他開63.5w, 送平整化，鍍膜，行車紀錄器，避光墊，我老婆說真便宜，我聽到這價格想走的，我開60萬他不接，看到一堆只有50幾萬的單，真羡慕
等競賽月吧！
依照過去慣例，今年競賽月有可能會落在6月份和7月份和8／1～8／21（鬼月前夕）延長賽，假如真是如此的話，7／20～7／31和8／10～8／21是比較好出手的時間點。
"""

# %%
import jieba.posseg as pseg
words = pseg.cut(text)
for w in words:
    print(w.word, w.flag)
# Out:
#  x
# 1. m
# 原廠 n
# 配件 n
# 還 d
# 有 v
# 在 p
# 賣 v
# 嗎 y
# ？ x
# 我 r
# 有 v
# 打 v
# 電話 n
# 問 n
# nissan eng
# 服務 vn
# 處 v
#
#  x
# 小姐 nr
# 說 v
# 只 d
# 聽 v
# 過 ug
# livina eng
# 的 uj
# ， x
# 沒 d
# 聽 v
# 過 ug
# 有 v
# new eng
#   x
# march eng
# 的 uj
# 。 x
#
#  x
# 2. m
# 有人 r
# 有 v
# 嗎 y
# ？ x
# 如果 c
# 有 v
# ， x
# 裝置 n
# 物盒 n
# ， x
# 後 nr
# 座 q
# 打平 v
# ， x
# 會 zg
# 完全 ad
# 平整 a
# 嗎 x
# ？ x
#
#  x
# 3. m
# 露天 v
# 、 x
# 拍賣 v
# 、 x
# 淘 v
# 寶 nr
#   x
# 我 r
# 都 d
# 找 v
# 不到 v
# 有 v
# 賣 v
#   x
# new eng
#   x
# march eng
#   x
# 後 nr
# 艙 n
# 平整 a
# 置 v
# 物盒 n
# 。 x
# 小弟 n
# 日前 t
# 購買 v
# 了 ul
# 一部 m
# a32 eng
#   x
# 3.0 m
#
#  x
# 目前 t
# 里程 n
# 約 d
# 9 m
# 萬 m
# 公里 q
#
#  x
# 有 v
# 需要 v
# 保養 v
# 維修 v
# 的 uj
# 項目 n
# 及 c
# 須 d
# 注意 v
# 什麼 r
# ? x
#
#  x
#
#  x
# 聽 x
# 朋友 n
# 說 v
# 車 n
# 上 f
# 最好 a
# 準備 v
# 一瓶 m
# 變速 v
# 箱油 n
# , x
# 因為 c
# 這款 r
# 車會 n
# 吃 v
# 油 n
# , x
# 是 v
# 這樣 r
# 嗎 y
# ? x
#
#  x
# 我 r
# 也 d
# 不 d
# 推薦 v
# 這間 r
#   x
# 我 r
# 的 uj
# 32 m
#   x
# 大概 d
# 4 x
# 年前 t
# 在 p
# ...

# %%
a={}
path = "C:\\Users\\BIG DATA\\PycharmProjects\\untitled\\textMining\\count\\Volkswagen2009.csv"
with open(path,'r', encoding='utf8') as frW:
        eng_stop_words = frW.read().split('\n')

eng_stop_words[0].split(',')[0]
for i in range(len(eng_stop_words)):
    try:
        ii = eng_stop_words[i].split(',')
#         print(ii[0])
        a[ii[0]]=int(ii[1])
    except Exception as e:
        pass
a
# Out:
# {'沒有': 477,
#  '原廠': 386,
#  '問題': 324,
#  '應該': 287,
#  '保養': 212,
#  '車子': 207,
#  '覺得': 183,
#  '保固': 174,
#  '感覺': 173,
#  '價格': 157,
#  '引擎': 155,
#  '謝謝': 149,
#  '台灣': 148,
#  '小弟': 141,
#  '時候': 132,
#  '不錯': 124,
#  '建議': 118,
#  '業代': 118,
#  '車主': 117,
#  '習慣': 95,
#  '配備': 94,
#  '聲音': 90,
#  '業務': 89,
#  '東西': 86,
#  '機油': 82,
#  '發現': 78,
#  '考慮': 78,
#  '福斯': 77,
#  '感謝': 76,
#  '新車': 75,
#  '車友': 75,
#  '柴油': 73,
#  '喜歡': 70,
#  '時間': 69,
#  '變速箱': 66,
#  '交車': 64,
#  '電腦': 63,
#  '技師': 63,
#  '空間': 61,
#  '起來': 59,
#  '維修': 59,
#  '汽車': 59,
#  '價錢': 58,
#  '參考': 55,
#  '德國': 53,
#  '檢查': 50,
#  '經驗': 49,
#  '看到': 49,
#  '開始': 49,
#  '內裝': 48,
#  '結果': 46,
#  '發生': 46,
#  '狀況': 46,
#  '輪胎': 46,
#  '系統': 45,
#  '油門': 44,
#  '樓主': 43,
#  '汽油': 43,
#  '知道': 42,
#  '油耗': 41,
#  '晶片': 40,
#  '進口': 40,
#  '好像': 40,
#  '出來': 39,
#  '車款': 39,
#  '開車': 38,
#  '車價': 38,
#  '便宜': 38,
#  '標達': 38,
#  '設計': 38,
#  '馬力': 37,
#  '渦輪': 37,
#  '動力': 36,
#  '處理': 36,
#  '歐洲': 35,
# ...

# %%
a = {'沒有': 477,
 '原廠': 386,
 '問題': 324,
 '應該': 287,
 '保養': 212,
 '車子': 207,
 '覺得': 183,
 '保固': 174,
 '感覺': 173,
 '價格': 157,
 '引擎': 155}
from pytagcloud import create_tag_image, make_tags
from IPython.display import Image
from operator import itemgetter
# print(a.items())
swd = [(k,a[k]) for k in sorted(a, key=a.get, reverse=True)]
print(swd[0:10][0])
swd = [w for w in swd[0:10] if len(w[0]) >= 2 and w[0] != '']
print(swd)
tags = make_tags(swd, maxsize=50)
print(tags)
create_tag_image(tags, './wc.png', size=(600,400), fontname='SimHei')
Image(filename='./wc.png')
# Out:
# ('沒有', 477)
# [('沒有', 477), ('原廠', 386), ('問題', 324), ('應該', 287), ('保養', 212), ('車子', 207), ('覺得', 183), ('保固', 174), ('感覺', 173), ('價格', 157)]
# [{'color': (153, 148, 26), 'size': 67, 'tag': '沒有'}, {'color': (204, 198, 167), 'size': 57, 'tag': '原廠'}, {'color': (60, 30, 202), 'size': 50, 'tag': '問題'}, {'color': (161, 146, 130), 'size': 46, 'tag': '應該'}, {'color': (107, 37, 180), 'size': 36, 'tag': '保養'}, {'color': (119, 108, 96), 'size': 36, 'tag': '車子'}, {'color': (84, 111, 167), 'size': 33, 'tag': '覺得'}, {'color': (55, 147, 71), 'size': 31, 'tag': '保固'}, {'color': (87, 212, 49), 'size': 31, 'tag': '感覺'}, {'color': (216, 88, 62), 'size': 29, 'tag': '價格'}]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-326b5adbb4b1> in <module>()
#      20 tags = make_tags(swd, maxsize=50)
#      21 print(tags)
# ...

# %%
#找出詞性
import jieba.posseg as pseg
verb = {}
adj = {}
noun = {}
for i in range(len(eng_stop_words)):
    ii = eng_stop_words[i].split(',')
    words = pseg.cut(ii[0])
    for w in words:
#         print(w.word, w.flag)
        if w.flag=="vn" or w.flag=="v":
#             print(w.word+" "+ii[1])
            v[w.word]=ii[1]
        elif w.flag=="an" or w.flag=="a":
            a[w.word]=ii[1]
#             print(w.word)
        else:
            n[w.word]=ii[1]
#             print(w.word)
with open(u'C:\\Users\\BIG DATA\\Desktop\\Project\\2009v.csv', 'a', encoding='utf8') as fw:
    for lang, counts in v.items():
        fw.write('{},{}\n'.format(lang, counts))
with open(u'C:\\Users\\BIG DATA\\Desktop\\Project\\2009n.csv', 'a', encoding='utf8') as fw4:
    for lang, counts in n.items():
        fw4.write('{},{}\n'.format(lang, counts))
with open(u'C:\\Users\\BIG DATA\\Desktop\\Project\\2009a.csv', 'a', encoding='utf8') as fw2:
    for lang, counts in a.items():
        fw2.write('{},{}\n'.format(lang, counts))

# %%
text2="結巴根本不會學習斷詞阿,load進去他也不會吃阿!真是笨死了,不信你看;汽車有智慧分配系統,他有切好嗎自動顯示幕!?"

# %%
import jieba
import jieba.posseg as pseg
jieba.load_userdict("C:\\Users\\BIG DATA\\Desktop\\Project\\textMining\\yahoo_content.txt")
words = pseg.cut(text2)
for w in words:
    print(w.word, w.flag)
# Out:
# 結巴 n
# 根本 a
# 不會學 l
# 習斷詞 i
# 阿 nr
# , x
# load eng
# 進去 v
# 他 r
# 也 d
# 不 d
# 會 v
# 吃 v
# 阿 nr
# ! x
# 真是 d
# 笨死了 l
# , x
# 不信 v
# 你 r
# 看 v
# ; x
# 汽車 n
# 有 v
# 智慧分配系統 x
# , x
# 他 r
# 有切 r
# 好 a
# 嗎 y
# 自動 x
# 顯示幕 x
# ! x
# ? x

# %%
#
import jieba
negativeDict_path = 'C:\\Users\\BIG DATA\\Desktop\\Project\\textMining\\sentiment\\negativeDict.txt'
positiveDict_path = 'C:\\Users\\BIG DATA\\Desktop\\Project\\textMining\\sentiment\\positiveDict.txt'
jieba.load_userdict(negativeDict_path)
jieba.load_userdict(positiveDict_path)
negativeDict = []
positiveDict = []
with open(negativeDict_path, 'r', encoding='utf8') as frW:
    negativeDict += frW.read().split('\n')
with open(positiveDict_path, 'r', encoding='utf8') as frW:
    positiveDict += frW.read().split('\n')
jieba_text = jieba.cut(text2,cut_all=False)
negativeDict_len = []
positiveDict_len = []
words = ','.join(jieba_text).split(',')
for word in words:
    if word in positiveDict:
        positiveDict_len.append(word)
    elif word in negativeDict:
        negativeDict_len.append(word)
print("negativeDict_list : ",negativeDict_len)
print("positiveDict_list : ",positiveDict_len)
if len(negativeDict_len)>len(positiveDict_len):
    print("negative")
else: 
    print("positive")
# Out:
# negativeDict2 :  ['結巴', '不會', '也不會', '不信']
# positiveDict2 :  ['根本', '自動']
# negative

# %%
#findSentenceINfeature
with open('C:\\jupyter\\textMining\\specialSignList.txt', "r", encoding='utf-8') as fr:
    stopWd = fr.read().strip().split('\n')
    cutlist = [signal for signal in stopWd if len(stopWd) > 0]
    
    
sentence = ""
textList = []
textList2 = []
print('\n',type(text))
# print(string)
for word in text:
    # print(word)
    if word not in cutlist:  # 如果文字不是標點符號，就把字加到句子中
        sentence += word
#         print(sentence)
    elif '業務' in sentence:
        textList.append(sentence)  # 如果遇到標點符號，把句子加到 text list中
        sentence = ""
    else :
        textList2.append(sentence)  # 如果遇到標點符號，把句子加到 text list中
        sentence = ""
print(textList)  # 傳回一個文字陣列
